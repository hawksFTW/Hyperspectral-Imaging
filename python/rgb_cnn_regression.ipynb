# %%
import os
import tensorflow
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import numpy as np
import argparse
import locale
import sys
# !pip install hdf5storage
import hdf5storage as hdf5

sys.path.insert(0,"/content/drive/My Drive/Hyperspectral")

from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
os.chdir("/content/gdrive/MyDrive/Hyperspectral/")
print(os.getcwd())
# !pip install hdf5storage
import datasets
import models
import cv2
# Out:
# Collecting hdf5storage
#   Downloading hdf5storage-0.1.18-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (1.21.5)
# Requirement already satisfied: h5py>=2.1 in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.1->hdf5storage) (1.5.2)
# Installing collected packages: hdf5storage
# Successfully installed hdf5storage-0.1.18
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Hyperspectral
# Requirement already satisfied: hdf5storage in /usr/local/lib/python3.7/dist-packages (0.1.18)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (1.21.5)
# Requirement already satisfied: h5py>=2.1 in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.1->hdf5storage) (1.5.2)

# %%
# load firmness
#inputPath = "c:\\users\\nalina\\Documents\\tomato_firmness\\hsdata\\firmness.csv"
inputPath = "/content/gdrive/MyDrive/Hyperspectral/hsdata/firmness.csv"
df = datasets.load_firmness_attributes(inputPath)
df.shape
# Out:
# (494, 1)

# %%
#load the hyperspectral images of tomatoes (3 channels) and scale the pixel 
rgbPath = "/content/gdrive/MyDrive/Hyperspectral/rgb"
#img = cv2.imread(rgbPath + "/" + "t18.jpeg")
#print(img.shape)

#images = datasets.load_produce_images(df_sub, inputPath)
inputImages = []
fileCount = 1
for i in df.index.values:
  if fileCount < 18:
    #print(fileCount)
    img = cv2.imread(rgbPath + "/" + i + ".jpg")
  else:
    img = cv2.imread(rgbPath + "/" + i + ".jpeg")
    #print(rgbPath + "/" + i + ".jpeg")
  #print(img.shape)
  img = img[0:482, 0:512, :]
  img = cv2.resize(img, (256, 256))
  #img_reshaped = img.reshape(img.shape[0], -1)
  #np.savetxt((img_path + i + ".txt"), img_reshaped, fmt='%d')
  inputImages.append(img)
  fileCount += 1

# %%
inputImages = np.array(inputImages)
inputImages.shape

# %%
split = train_test_split(df, inputImages, test_size=0.25, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split

trainY = np.log(trainAttrX["firmness"])
testY = np.log(testAttrX["firmness"])

# %%
# create our Convolutional Neural Network and then compile the model
# using mean absolute percentage error as our loss, implying that we
# seek to minimize the absolute percentage difference between our
# predicted firmness and the actual firmness
model = models.create_cnn(256, 256, 3, regress=True)
opt = Adam(lr=1e-4, decay=1e-3 / 200)
model.compile(loss="mean_squared_error", optimizer=opt)

history = model.fit(x=trainImagesX, y=trainY, validation_data=(testImagesX, testY), epochs=125, batch_size=32) #try epochs=200 if this works, error goes down until 125

#firmness predictions for test data
#firmness_preds = model.predict(testImagesX)

#compute the difference between the firmness predictions and the actual firmness values, then compute the percentage 
#difference and the absolute percentage difference
#diff = firmness_preds.flatten() - testY
#percent_diff = (diff / testY) * 100
#absPercentDiff = np.abs(percent_diff)

#mean and std deviation of absolute percentage difference
#mean = np.mean(absPercentDiff)
#std = np.abs(absPercentDiff)
#######################################

#print("Avg. firmness " + str(df["firmness"].mean()))
#print("Std. Dev. firmness " + str(df["firmness"].std()))

#print("Mean and std. dev. of predictions " + str(mean) + " " + str(std))

# %%
import matplotlib.pyplot as plt

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import pandas as pd
#testY = testAttrX["firmness"] / maxFirmness
#firmness predictions for test data
firmness_preds = model.predict(testImagesX)
testY = pd.DataFrame(testY)
testY['preds'] = firmness_preds.flatten()
testY.to_csv("/content/gdrive/MyDrive/Hyperspectral/hsdata/test_preds_256rs_125epochs_v3.csv", index=False)

# %%
d = {'train_loss': history.history['loss'], 'test_loss': history.history['val_loss']}
model_acc = pd.DataFrame(d)
model_acc.to_csv("/content/gdrive/MyDrive/Hyperspectral/hsdata/model_acc_256rs_125epochs_v3.csv", index=False)

# %%
################# NEURAL NETWORK ############################
#load the hyperspectral images of tomatoes (31 channels) and scale the pixel to 128 or 64 for NN since only a single dimension can be input 128*128*31 or 64*64*31
rgbPath = "/content/gdrive/MyDrive/Hyperspectral/rgb"
inputNNImages = []
fileCount = 1
for i in df.index.values:
  if fileCount < 18:
    img = cv2.imread(rgbPath + "/" + i + ".jpg")
  else:
    img = cv2.imread(rgbPath + "/" + i + ".jpeg")
  img = img[0:482, 0:512, :]
  img = cv2.resize(img, (128, 128))
  inputNNImages.append(img)
  fileCount += 1

# %%
inputNNImages = np.array(inputNNImages)

# %%
inputNNImages.shape
# Out:
# (494, 128, 128, 3)

# %%
split = train_test_split(df, inputNNImages, test_size=0.25, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split

trainY = np.log(trainAttrX["firmness"])
testY = np.log(testAttrX["firmness"])

# %%
#flatten the trainImagesX and testImagesX to convert from 3 dimensions to 1 dimension
nn_trainx = trainImagesX.reshape(trainImagesX.shape[0],-1)
nn_testx = testImagesX.reshape(testImagesX.shape[0],-1)
print(nn_trainx.shape)
# Out:
# (370, 49152)

# %%
# create our Neural Network and then compile the model
# using mean absolute percentage error as our loss, implying that we
# seek to minimize the absolute percentage difference between our
# predicted firmness and the actual firmness
model = models.create_mlp(49152, regress=True)
opt = Adam(lr=1e-4, decay=1e-3 / 200)
model.compile(loss="mean_squared_error", optimizer=opt)

nn_history = model.fit(x=nn_trainx, y=trainY, validation_data=(nn_testx, testY), epochs=125, batch_size=32) #try epochs=200 if this works

#firmness predictions for test data
nn_firmness_preds = model.predict(nn_testx)

#compute the difference between the firmness predictions and the actual firmness values, then compute the percentage 
#difference and the absolute percentage difference
#nn_diff = firmness_preds.flatten() - testY
#nn_percent_diff = (nn_diff / testY) * 100
#nn_absPercentDiff = np.abs(nn_percent_diff)

#mean and std deviation of absolute percentage difference
#nn_mean = np.mean(nn_absPercentDiff)
#nn_std = np.abs(nn_absPercentDiff)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/125
# 12/12 [==============================] - 1s 20ms/step - loss: 2423.1143 - val_loss: 7.0447
# Epoch 2/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0177 - val_loss: 7.0442
# Epoch 3/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0172 - val_loss: 7.0435
# Epoch 4/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0165 - val_loss: 7.0428
# Epoch 5/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0158 - val_loss: 7.0420
# Epoch 6/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0150 - val_loss: 7.0412
# Epoch 7/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0140 - val_loss: 7.0402
# Epoch 8/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0131 - val_loss: 7.0392
# Epoch 9/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0120 - val_loss: 7.0381
# Epoch 10/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0109 - val_loss: 7.0370
# Epoch 11/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0097 - val_loss: 7.0357
# Epoch 12/125
# 12/12 [==============================] - 0s 9ms/step - loss: 7.0085 - val_loss: 7.0345
# Epoch 13/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0072 - val_loss: 7.0332
# Epoch 14/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0059 - val_loss: 7.0318
# Epoch 15/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0045 - val_loss: 7.0304
# Epoch 16/125
# 12/12 [==============================] - 0s 9ms/step - loss: 7.0030 - val_loss: 7.0289
# Epoch 17/125
# 12/12 [==============================] - 0s 8ms/step - loss: 7.0015 - val_loss: 7.0273
# Epoch 18/125
# 12/12 [==============================] - 0s 9ms/step - loss: 7.0000 - val_loss: 7.0258
# Epoch 19/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9984 - val_loss: 7.0242
# Epoch 20/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9968 - val_loss: 7.0225
# Epoch 21/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9951 - val_loss: 7.0208
# Epoch 22/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9934 - val_loss: 7.0190
# Epoch 23/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9916 - val_loss: 7.0173
# Epoch 24/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9898 - val_loss: 7.0154
# Epoch 25/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9880 - val_loss: 7.0135
# Epoch 26/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9861 - val_loss: 7.0116
# Epoch 27/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9842 - val_loss: 7.0097
# Epoch 28/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9822 - val_loss: 7.0077
# Epoch 29/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9802 - val_loss: 7.0057
# Epoch 30/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9782 - val_loss: 7.0036
# Epoch 31/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9761 - val_loss: 7.0015
# Epoch 32/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9740 - val_loss: 6.9994
# Epoch 33/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9719 - val_loss: 6.9972
# Epoch 34/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9697 - val_loss: 6.9950
# Epoch 35/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9675 - val_loss: 6.9928
# Epoch 36/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9653 - val_loss: 6.9905
# Epoch 37/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9630 - val_loss: 6.9882
# Epoch 38/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9607 - val_loss: 6.9859
# Epoch 39/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9584 - val_loss: 6.9835
# Epoch 40/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9560 - val_loss: 6.9811
# Epoch 41/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9536 - val_loss: 6.9787
# Epoch 42/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9512 - val_loss: 6.9762
# Epoch 43/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9487 - val_loss: 6.9738
# Epoch 44/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9462 - val_loss: 6.9712
# Epoch 45/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9437 - val_loss: 6.9687
# Epoch 46/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9411 - val_loss: 6.9661
# Epoch 47/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9385 - val_loss: 6.9635
# Epoch 48/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9359 - val_loss: 6.9609
# Epoch 49/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9333 - val_loss: 6.9582
# Epoch 50/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9306 - val_loss: 6.9555
# Epoch 51/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9279 - val_loss: 6.9528
# Epoch 52/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.9252 - val_loss: 6.9500
# Epoch 53/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9224 - val_loss: 6.9473
# Epoch 54/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9197 - val_loss: 6.9445
# Epoch 55/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9169 - val_loss: 6.9416
# Epoch 56/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9140 - val_loss: 6.9388
# Epoch 57/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9112 - val_loss: 6.9359
# Epoch 58/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9083 - val_loss: 6.9330
# Epoch 59/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9054 - val_loss: 6.9300
# Epoch 60/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.9024 - val_loss: 6.9271
# Epoch 61/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8995 - val_loss: 6.9241
# Epoch 62/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8965 - val_loss: 6.9211
# Epoch 63/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8935 - val_loss: 6.9180
# Epoch 64/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8904 - val_loss: 6.9150
# Epoch 65/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8874 - val_loss: 6.9119
# Epoch 66/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8843 - val_loss: 6.9088
# Epoch 67/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8811 - val_loss: 6.9056
# Epoch 68/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8780 - val_loss: 6.9025
# Epoch 69/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8748 - val_loss: 6.8993
# Epoch 70/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8717 - val_loss: 6.8961
# Epoch 71/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8685 - val_loss: 6.8928
# Epoch 72/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8652 - val_loss: 6.8896
# Epoch 73/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8620 - val_loss: 6.8863
# Epoch 74/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8587 - val_loss: 6.8830
# Epoch 75/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8554 - val_loss: 6.8797
# Epoch 76/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8521 - val_loss: 6.8764
# Epoch 77/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8488 - val_loss: 6.8730
# Epoch 78/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8454 - val_loss: 6.8696
# Epoch 79/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8420 - val_loss: 6.8662
# Epoch 80/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8386 - val_loss: 6.8628
# Epoch 81/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8352 - val_loss: 6.8593
# Epoch 82/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8318 - val_loss: 6.8559
# Epoch 83/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8283 - val_loss: 6.8524
# Epoch 84/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8248 - val_loss: 6.8489
# Epoch 85/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8213 - val_loss: 6.8453
# Epoch 86/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8178 - val_loss: 6.8418
# Epoch 87/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8142 - val_loss: 6.8382
# Epoch 88/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8107 - val_loss: 6.8346
# Epoch 89/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.8071 - val_loss: 6.8310
# Epoch 90/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.8035 - val_loss: 6.8274
# Epoch 91/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7998 - val_loss: 6.8237
# Epoch 92/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7962 - val_loss: 6.8201
# Epoch 93/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7925 - val_loss: 6.8164
# Epoch 94/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7889 - val_loss: 6.8127
# Epoch 95/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7852 - val_loss: 6.8089
# Epoch 96/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7814 - val_loss: 6.8052
# Epoch 97/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7777 - val_loss: 6.8014
# Epoch 98/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7739 - val_loss: 6.7976
# Epoch 99/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7702 - val_loss: 6.7938
# Epoch 100/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7664 - val_loss: 6.7900
# Epoch 101/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7625 - val_loss: 6.7862
# Epoch 102/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7587 - val_loss: 6.7823
# Epoch 103/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7549 - val_loss: 6.7785
# Epoch 104/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7510 - val_loss: 6.7746
# Epoch 105/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7471 - val_loss: 6.7707
# Epoch 106/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7432 - val_loss: 6.7668
# Epoch 107/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7393 - val_loss: 6.7628
# Epoch 108/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7354 - val_loss: 6.7589
# Epoch 109/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7314 - val_loss: 6.7549
# Epoch 110/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7275 - val_loss: 6.7509
# Epoch 111/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7235 - val_loss: 6.7469
# Epoch 112/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7195 - val_loss: 6.7429
# Epoch 113/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7155 - val_loss: 6.7388
# Epoch 114/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7114 - val_loss: 6.7348
# Epoch 115/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.7074 - val_loss: 6.7307
# Epoch 116/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.7033 - val_loss: 6.7266
# Epoch 117/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.6993 - val_loss: 6.7225
# Epoch 118/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.6952 - val_loss: 6.7184
# Epoch 119/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.6911 - val_loss: 6.7143
# Epoch 120/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.6869 - val_loss: 6.7101
# Epoch 121/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.6828 - val_loss: 6.7060
# Epoch 122/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.6787 - val_loss: 6.7018
# Epoch 123/125
# 12/12 [==============================] - 0s 9ms/step - loss: 6.6745 - val_loss: 6.6976
# Epoch 124/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.6703 - val_loss: 6.6934
# Epoch 125/125
# 12/12 [==============================] - 0s 8ms/step - loss: 6.6661 - val_loss: 6.6892

# %%
import matplotlib.pyplot as plt

print(nn_history.history.keys())
# summarize history for accuracy
plt.plot(nn_history.history['loss'])
plt.plot(nn_history.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
import pandas as pd
#testY = testAttrX["firmness"] / maxFirmness
#firmness predictions for test data
nn_firmness_preds = model.predict(nn_testx)
testY = pd.DataFrame(testY)
testY['preds'] = nn_firmness_preds.flatten()
testY.to_csv("/content/gdrive/MyDrive/Hyperspectral/hsdata/nn_test_preds_256rs_125epochs_rgb.csv", index=False)

# %%
d = {'train_loss': nn_history.history['loss'], 'test_loss': nn_history.history['val_loss']}
model_acc = pd.DataFrame(d)
model_acc.to_csv("/content/gdrive/MyDrive/Hyperspectral/hsdata/nn_model_acc_256rs_125epochs_rgb.csv", index=False)
