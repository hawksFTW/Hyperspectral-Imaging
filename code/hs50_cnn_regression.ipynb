# %%
import os
import tensorflow
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import numpy as np
import argparse
import locale
import sys
# !pip install hdf5storage
import hdf5storage as hdf5

sys.path.insert(0,"/content/drive/My Drive/Hyperspectral")

from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
os.chdir("/content/gdrive/MyDrive/Hyperspectral/")
print(os.getcwd())
# !pip install hdf5storage
import datasets
import models
import cv2
# Out:
# Collecting hdf5storage
#   Downloading hdf5storage-0.1.18-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.7 MB/s
# Requirement already satisfied: h5py>=2.1 in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (1.21.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.1->hdf5storage) (1.5.2)
# Installing collected packages: hdf5storage
# Successfully installed hdf5storage-0.1.18
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Hyperspectral
# Requirement already satisfied: hdf5storage in /usr/local/lib/python3.7/dist-packages (0.1.18)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (1.21.5)
# Requirement already satisfied: h5py>=2.1 in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.1->hdf5storage) (1.5.2)

# %%
# load firmness
#inputPath = "c:\\users\\nalina\\Documents\\tomato_firmness\\hsdata\\firmness.csv"
#inputPath = "/content/gdrive/MyDrive/Hyperspectral/hsdata50/firmness_hs50_omit.csv"
inputPath = "/content/gdrive/MyDrive/Hyperspectral/hsdata50/firmness_hs50.csv"
df = datasets.load_firmness_attributes(inputPath)
df.shape
# Out:
# (371, 1)

# %%
#load the hyperspectral images of tomatoes (50 channels) and scale the pixel 
inputPath = "/content/gdrive/MyDrive/Hyperspectral/hsdata50/"
#images = datasets.load_produce_images(df_sub, inputPath)
inputImages = []
fileCount = 1
for i in df.index.values:
  filename = "reconCube" + i[1:] + ".txt"
  img = np.loadtxt(inputPath  + filename)
  img = img.reshape((50,88,88))
  img = img.reshape(88,88,50)
  #img_reshaped = img.reshape(img.shape[0], -1)
  #print(img_reshaped.shape)
  #np.savetxt((img_path + i + ".txt"), img_reshaped, fmt='%d')
  #img = spectral[i, :, :]
  filenum = int(filename.partition('.')[0][9:])
  #if (filenum >= 11 and filenum <= 392):
  #  img = img*0.5
  #else:
  #  img = img*0.2
  inputImages.append(img)
  fileCount += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c4751f90e5d> in <module>()
#       4 inputImages = []
#       5 fileCount = 1
# ----> 6 for i in df.index.values:
#       7   filename = "reconCube" + i[1:] + ".txt"
#       8   img = np.loadtxt(inputPath  + filename)
#
# NameError: name 'df' is not defined

# %%
inputImages = np.array(inputImages)
#inputImages1 = inputImages.reshape
inputImages.shape
# Out:
# (371, 88, 88, 50)

# %%
split = train_test_split(df, inputImages, test_size=0.25, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split

trainY = np.log(trainAttrX["firmness"])
testY = np.log(testAttrX["firmness"])
print(trainImagesX.shape)
# Out:
# (278, 88, 88, 50)

# %%
# create our Convolutional Neural Network and then compile the model
# using mean absolute percentage error as our loss, implying that we
# seek to minimize the absolute percentage difference between our
# predicted firmness and the actual firmness
model = models.create_cnn(88, 88, 50, regress=True)
opt = Adam(lr=1e-4, decay=1e-3 / 200)
model.compile(loss="mean_squared_error", optimizer=opt)

history = model.fit(x=trainImagesX, y=trainY, validation_data=(testImagesX, testY), epochs=200, batch_size=32) #try epochs=200 if this works, error goes down until 125

#firmness predictions for test data
#firmness_preds = model.predict(testImagesX)

#compute the difference between the firmness predictions and the actual firmness values, then compute the percentage 
#difference and the absolute percentage difference
#diff = firmness_preds.flatten() - testY
#percent_diff = (diff / testY) * 100
#absPercentDiff = np.abs(percent_diff)

#mean and std deviation of absolute percentage difference
#mean = np.mean(absPercentDiff)
#std = np.abs(absPercentDiff)
#######################################

#print("Avg. firmness " + str(df["firmness"].mean()))
#print("Std. Dev. firmness " + str(df["firmness"].std()))

#print("Mean and std. dev. of predictions " + str(mean) + " " + str(std))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/200
# 9/9 [==============================] - 5s 408ms/step - loss: 3.4073 - val_loss: 4.1149
# Epoch 2/200
# 9/9 [==============================] - 3s 379ms/step - loss: 2.8291 - val_loss: 6.6432
# Epoch 3/200
# 9/9 [==============================] - 3s 372ms/step - loss: 2.6359 - val_loss: 6.8513
# Epoch 4/200
# 9/9 [==============================] - 3s 376ms/step - loss: 2.6349 - val_loss: 6.2040
# Epoch 5/200
# 9/9 [==============================] - 3s 373ms/step - loss: 2.6128 - val_loss: 5.5196
# Epoch 6/200
# 9/9 [==============================] - 3s 378ms/step - loss: 2.1917 - val_loss: 5.0299
# Epoch 7/200
# 9/9 [==============================] - 3s 385ms/step - loss: 2.2695 - val_loss: 4.2371
# Epoch 8/200
# 9/9 [==============================] - 3s 376ms/step - loss: 2.1627 - val_loss: 3.8248
# Epoch 9/200
# 9/9 [==============================] - 3s 378ms/step - loss: 1.9434 - val_loss: 3.6706
# Epoch 10/200
# 9/9 [==============================] - 3s 371ms/step - loss: 1.7953 - val_loss: 3.5111
# Epoch 11/200
# 9/9 [==============================] - 3s 375ms/step - loss: 1.7617 - val_loss: 3.2641
# Epoch 12/200
# 9/9 [==============================] - 3s 370ms/step - loss: 1.7453 - val_loss: 2.9968
# Epoch 13/200
# 9/9 [==============================] - 3s 370ms/step - loss: 1.6554 - val_loss: 2.5124
# Epoch 14/200
# 9/9 [==============================] - 3s 371ms/step - loss: 1.4991 - val_loss: 2.3763
# Epoch 15/200
# 9/9 [==============================] - 3s 372ms/step - loss: 1.5501 - val_loss: 2.3425
# Epoch 16/200
# 9/9 [==============================] - 3s 371ms/step - loss: 1.5587 - val_loss: 2.0387
# Epoch 17/200
# 9/9 [==============================] - 3s 374ms/step - loss: 1.4420 - val_loss: 1.8123
# Epoch 18/200
# 9/9 [==============================] - 3s 376ms/step - loss: 1.5989 - val_loss: 1.6571
# Epoch 19/200
# 9/9 [==============================] - 3s 373ms/step - loss: 1.3915 - val_loss: 1.5823
# Epoch 20/200
# 9/9 [==============================] - 3s 371ms/step - loss: 1.4082 - val_loss: 1.4953
# Epoch 21/200
# 9/9 [==============================] - 3s 374ms/step - loss: 1.2742 - val_loss: 1.3934
# Epoch 22/200
# 9/9 [==============================] - 3s 378ms/step - loss: 1.3251 - val_loss: 1.3393
# Epoch 23/200
# 9/9 [==============================] - 3s 370ms/step - loss: 1.2271 - val_loss: 1.3049
# Epoch 24/200
# 9/9 [==============================] - 3s 371ms/step - loss: 1.1774 - val_loss: 1.2078
# Epoch 25/200
# 9/9 [==============================] - 3s 375ms/step - loss: 1.1197 - val_loss: 1.1659
# Epoch 26/200
# 9/9 [==============================] - 3s 378ms/step - loss: 1.1453 - val_loss: 1.0666
# Epoch 27/200
# 9/9 [==============================] - 3s 372ms/step - loss: 1.2120 - val_loss: 1.0338
# Epoch 28/200
# 9/9 [==============================] - 3s 375ms/step - loss: 1.0464 - val_loss: 0.9928
# Epoch 29/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.9810 - val_loss: 0.9969
# Epoch 30/200
# 9/9 [==============================] - 3s 375ms/step - loss: 1.0330 - val_loss: 0.9819
# Epoch 31/200
# 9/9 [==============================] - 3s 370ms/step - loss: 1.2213 - val_loss: 0.9704
# Epoch 32/200
# 9/9 [==============================] - 3s 371ms/step - loss: 1.1041 - val_loss: 1.0409
# Epoch 33/200
# 9/9 [==============================] - 3s 374ms/step - loss: 1.0953 - val_loss: 1.0724
# Epoch 34/200
# 9/9 [==============================] - 3s 374ms/step - loss: 1.0426 - val_loss: 1.0073
# Epoch 35/200
# 9/9 [==============================] - 3s 377ms/step - loss: 1.0669 - val_loss: 0.9094
# Epoch 36/200
# 9/9 [==============================] - 3s 374ms/step - loss: 1.0492 - val_loss: 0.9310
# Epoch 37/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.9902 - val_loss: 0.8458
# Epoch 38/200
# 9/9 [==============================] - 3s 372ms/step - loss: 1.0487 - val_loss: 0.8012
# Epoch 39/200
# 9/9 [==============================] - 3s 374ms/step - loss: 1.0292 - val_loss: 0.7984
# Epoch 40/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.9086 - val_loss: 0.8207
# Epoch 41/200
# 9/9 [==============================] - 3s 373ms/step - loss: 1.0475 - val_loss: 0.8466
# Epoch 42/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.9833 - val_loss: 0.8394
# Epoch 43/200
# 9/9 [==============================] - 3s 376ms/step - loss: 1.0010 - val_loss: 0.7780
# Epoch 44/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.8827 - val_loss: 0.7267
# Epoch 45/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.9346 - val_loss: 0.6656
# Epoch 46/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.8431 - val_loss: 0.6438
# Epoch 47/200
# 9/9 [==============================] - 3s 376ms/step - loss: 1.0303 - val_loss: 0.7303
# Epoch 48/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.8826 - val_loss: 0.7218
# Epoch 49/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.8115 - val_loss: 0.6845
# Epoch 50/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.8460 - val_loss: 0.6500
# Epoch 51/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.9219 - val_loss: 0.5825
# Epoch 52/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.7992 - val_loss: 0.5854
# Epoch 53/200
# 9/9 [==============================] - 3s 372ms/step - loss: 0.8784 - val_loss: 0.6287
# Epoch 54/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.7635 - val_loss: 0.6813
# Epoch 55/200
# 9/9 [==============================] - 3s 371ms/step - loss: 0.7410 - val_loss: 0.8079
# Epoch 56/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.9178 - val_loss: 0.7556
# Epoch 57/200
# 9/9 [==============================] - 3s 374ms/step - loss: 1.0068 - val_loss: 0.6146
# Epoch 58/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.8737 - val_loss: 0.6067
# Epoch 59/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.7245 - val_loss: 0.5982
# Epoch 60/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.9376 - val_loss: 0.5361
# Epoch 61/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.9096 - val_loss: 0.5198
# Epoch 62/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.8585 - val_loss: 0.5345
# Epoch 63/200
# 9/9 [==============================] - 3s 372ms/step - loss: 0.7031 - val_loss: 0.5182
# Epoch 64/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.7033 - val_loss: 0.5033
# Epoch 65/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.8117 - val_loss: 0.5007
# Epoch 66/200
# 9/9 [==============================] - 3s 367ms/step - loss: 0.7149 - val_loss: 0.5297
# Epoch 67/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.7959 - val_loss: 0.4798
# Epoch 68/200
# 9/9 [==============================] - 3s 371ms/step - loss: 0.9032 - val_loss: 0.4632
# Epoch 69/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.7664 - val_loss: 0.4439
# Epoch 70/200
# 9/9 [==============================] - 3s 382ms/step - loss: 0.8533 - val_loss: 0.4839
# Epoch 71/200
# 9/9 [==============================] - 4s 425ms/step - loss: 0.8842 - val_loss: 0.5193
# Epoch 72/200
# 9/9 [==============================] - 4s 453ms/step - loss: 0.7663 - val_loss: 0.5139
# Epoch 73/200
# 9/9 [==============================] - 4s 414ms/step - loss: 0.8160 - val_loss: 0.5236
# Epoch 74/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.7487 - val_loss: 0.5364
# Epoch 75/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.7122 - val_loss: 0.5478
# Epoch 76/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.8173 - val_loss: 0.5061
# Epoch 77/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.6604 - val_loss: 0.4772
# Epoch 78/200
# 9/9 [==============================] - 3s 371ms/step - loss: 0.7550 - val_loss: 0.4383
# Epoch 79/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.6859 - val_loss: 0.4261
# Epoch 80/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.8103 - val_loss: 0.4207
# Epoch 81/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.8633 - val_loss: 0.3944
# Epoch 82/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.8527 - val_loss: 0.3997
# Epoch 83/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.7218 - val_loss: 0.3973
# Epoch 84/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.8446 - val_loss: 0.4032
# Epoch 85/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.7105 - val_loss: 0.4414
# Epoch 86/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.7571 - val_loss: 0.4009
# Epoch 87/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.7555 - val_loss: 0.4395
# Epoch 88/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.7419 - val_loss: 0.5219
# Epoch 89/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.7015 - val_loss: 0.4882
# Epoch 90/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6675 - val_loss: 0.4929
# Epoch 91/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.7245 - val_loss: 0.4637
# Epoch 92/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.7177 - val_loss: 0.4634
# Epoch 93/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.6505 - val_loss: 0.5004
# Epoch 94/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.6151 - val_loss: 0.4640
# Epoch 95/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.7838 - val_loss: 0.5032
# Epoch 96/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.6137 - val_loss: 0.5459
# Epoch 97/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.7753 - val_loss: 0.5402
# Epoch 98/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.7222 - val_loss: 0.4917
# Epoch 99/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.7186 - val_loss: 0.4626
# Epoch 100/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.8283 - val_loss: 0.4645
# Epoch 101/200
# 9/9 [==============================] - 3s 380ms/step - loss: 0.7201 - val_loss: 0.4890
# Epoch 102/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.6278 - val_loss: 0.4885
# Epoch 103/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.7195 - val_loss: 0.4563
# Epoch 104/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.7260 - val_loss: 0.4389
# Epoch 105/200
# 9/9 [==============================] - 3s 380ms/step - loss: 0.7059 - val_loss: 0.4662
# Epoch 106/200
# 9/9 [==============================] - 3s 381ms/step - loss: 0.7345 - val_loss: 0.4486
# Epoch 107/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.7513 - val_loss: 0.4402
# Epoch 108/200
# 9/9 [==============================] - 3s 380ms/step - loss: 0.8027 - val_loss: 0.3709
# Epoch 109/200
# 9/9 [==============================] - 3s 381ms/step - loss: 0.6574 - val_loss: 0.3845
# Epoch 110/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.7162 - val_loss: 0.4131
# Epoch 111/200
# 9/9 [==============================] - 3s 372ms/step - loss: 0.7202 - val_loss: 0.4379
# Epoch 112/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6955 - val_loss: 0.4526
# Epoch 113/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.5665 - val_loss: 0.4338
# Epoch 114/200
# 9/9 [==============================] - 3s 382ms/step - loss: 0.5918 - val_loss: 0.4232
# Epoch 115/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.7468 - val_loss: 0.4807
# Epoch 116/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.7139 - val_loss: 0.5021
# Epoch 117/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6683 - val_loss: 0.4585
# Epoch 118/200
# 9/9 [==============================] - 3s 372ms/step - loss: 0.7236 - val_loss: 0.4727
# Epoch 119/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.6734 - val_loss: 0.4797
# Epoch 120/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.6029 - val_loss: 0.4796
# Epoch 121/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6771 - val_loss: 0.4427
# Epoch 122/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.7171 - val_loss: 0.4409
# Epoch 123/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.6137 - val_loss: 0.4773
# Epoch 124/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.5914 - val_loss: 0.5327
# Epoch 125/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.7579 - val_loss: 0.4497
# Epoch 126/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.5404 - val_loss: 0.4653
# Epoch 127/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6774 - val_loss: 0.4179
# Epoch 128/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.6682 - val_loss: 0.4112
# Epoch 129/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.5956 - val_loss: 0.4265
# Epoch 130/200
# 9/9 [==============================] - 3s 380ms/step - loss: 0.6980 - val_loss: 0.4323
# Epoch 131/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.6844 - val_loss: 0.3876
# Epoch 132/200
# 9/9 [==============================] - 3s 373ms/step - loss: 0.7648 - val_loss: 0.3827
# Epoch 133/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.6360 - val_loss: 0.3699
# Epoch 134/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.5680 - val_loss: 0.3641
# Epoch 135/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.6729 - val_loss: 0.3607
# Epoch 136/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.5639 - val_loss: 0.3626
# Epoch 137/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.5845 - val_loss: 0.3353
# Epoch 138/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.4774 - val_loss: 0.3088
# Epoch 139/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.6731 - val_loss: 0.3020
# Epoch 140/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.6560 - val_loss: 0.3047
# Epoch 141/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.6999 - val_loss: 0.2686
# Epoch 142/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.5916 - val_loss: 0.3180
# Epoch 143/200
# 9/9 [==============================] - 3s 383ms/step - loss: 0.7173 - val_loss: 0.3911
# Epoch 144/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.7212 - val_loss: 0.3712
# Epoch 145/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.5534 - val_loss: 0.3933
# Epoch 146/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.5670 - val_loss: 0.3799
# Epoch 147/200
# 9/9 [==============================] - 3s 383ms/step - loss: 0.6140 - val_loss: 0.3650
# Epoch 148/200
# 9/9 [==============================] - 3s 380ms/step - loss: 0.6304 - val_loss: 0.3639
# Epoch 149/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.6164 - val_loss: 0.3461
# Epoch 150/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.5739 - val_loss: 0.2965
# Epoch 151/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.6579 - val_loss: 0.2826
# Epoch 152/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.5373 - val_loss: 0.3166
# Epoch 153/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6118 - val_loss: 0.3166
# Epoch 154/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6302 - val_loss: 0.3033
# Epoch 155/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.6400 - val_loss: 0.2989
# Epoch 156/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.5355 - val_loss: 0.3060
# Epoch 157/200
# 9/9 [==============================] - 3s 371ms/step - loss: 0.5364 - val_loss: 0.3300
# Epoch 158/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6100 - val_loss: 0.3305
# Epoch 159/200
# 9/9 [==============================] - 3s 372ms/step - loss: 0.5390 - val_loss: 0.3310
# Epoch 160/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.5881 - val_loss: 0.3574
# Epoch 161/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.5789 - val_loss: 0.4387
# Epoch 162/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6260 - val_loss: 0.3578
# Epoch 163/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.4943 - val_loss: 0.3656
# Epoch 164/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.5890 - val_loss: 0.3739
# Epoch 165/200
# 9/9 [==============================] - 3s 372ms/step - loss: 0.6968 - val_loss: 0.3057
# Epoch 166/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.6167 - val_loss: 0.3422
# Epoch 167/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.6604 - val_loss: 0.3460
# Epoch 168/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.6204 - val_loss: 0.3600
# Epoch 169/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.6349 - val_loss: 0.3940
# Epoch 170/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.6527 - val_loss: 0.3651
# Epoch 171/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.5459 - val_loss: 0.3404
# Epoch 172/200
# 9/9 [==============================] - 3s 377ms/step - loss: 0.6003 - val_loss: 0.3464
# Epoch 173/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.6206 - val_loss: 0.3730
# Epoch 174/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.6325 - val_loss: 0.3997
# Epoch 175/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.5575 - val_loss: 0.4033
# Epoch 176/200
# 9/9 [==============================] - 3s 384ms/step - loss: 0.5896 - val_loss: 0.3467
# Epoch 177/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.4709 - val_loss: 0.3476
# Epoch 178/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.5886 - val_loss: 0.3597
# Epoch 179/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.5873 - val_loss: 0.3638
# Epoch 180/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.5298 - val_loss: 0.3692
# Epoch 181/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.6448 - val_loss: 0.3965
# Epoch 182/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.6148 - val_loss: 0.4423
# Epoch 183/200
# 9/9 [==============================] - 3s 380ms/step - loss: 0.5591 - val_loss: 0.4593
# Epoch 184/200
# 9/9 [==============================] - 3s 381ms/step - loss: 0.6139 - val_loss: 0.4210
# Epoch 185/200
# 9/9 [==============================] - 3s 380ms/step - loss: 0.5496 - val_loss: 0.3773
# Epoch 186/200
# 9/9 [==============================] - 3s 381ms/step - loss: 0.6159 - val_loss: 0.3507
# Epoch 187/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.5241 - val_loss: 0.3492
# Epoch 188/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.6232 - val_loss: 0.3397
# Epoch 189/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.5706 - val_loss: 0.3603
# Epoch 190/200
# 9/9 [==============================] - 3s 375ms/step - loss: 0.5222 - val_loss: 0.4355
# Epoch 191/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.5416 - val_loss: 0.5106
# Epoch 192/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.5899 - val_loss: 0.4542
# Epoch 193/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.5408 - val_loss: 0.4178
# Epoch 194/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.7056 - val_loss: 0.4341
# Epoch 195/200
# 9/9 [==============================] - 3s 379ms/step - loss: 0.5958 - val_loss: 0.4493
# Epoch 196/200
# 9/9 [==============================] - 3s 374ms/step - loss: 0.6288 - val_loss: 0.3948
# Epoch 197/200
# 9/9 [==============================] - 3s 376ms/step - loss: 0.5410 - val_loss: 0.4487
# Epoch 198/200
# 9/9 [==============================] - 3s 382ms/step - loss: 0.4870 - val_loss: 0.5615
# Epoch 199/200
# 9/9 [==============================] - 3s 378ms/step - loss: 0.5457 - val_loss: 0.5381
# Epoch 200/200
# 9/9 [==============================] - 3s 372ms/step - loss: 0.5285 - val_loss: 0.4885

# %%
import matplotlib.pyplot as plt

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6f3fe5a26250> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 print(history.history.keys())
#       4 # summarize history for accuracy
#       5 plt.plot(history.history['loss'])
#
# NameError: name 'history' is not defined

# %%
import pandas as pd
#testY = testAttrX["firmness"] / maxFirmness
#firmness predictions for test data
firmness_preds = model.predict(testImagesX)
testY = pd.DataFrame(testY)
testY['preds'] = firmness_preds.flatten()
testY.to_csv("/content/gdrive/MyDrive/Hyperspectral/hsdata50/test_preds_200epochs_v4.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5f2987a73bed> in <module>()
#       2 #testY = testAttrX["firmness"] / maxFirmness
#       3 #firmness predictions for test data
# ----> 4 firmness_preds = model.predict(testImagesX)
#       5 testY = pd.DataFrame(testY)
#       6 testY['preds'] = firmness_preds.flatten()
#
# NameError: name 'model' is not defined

# %%
d = {'train_loss': history.history['loss'], 'test_loss': history.history['val_loss']}
model_acc = pd.DataFrame(d)
model_acc.to_csv("/content/gdrive/MyDrive/Hyperspectral/hsdata50/model_acc_200epochs_v4.csv", index=False)

# %%
inputNNImages = inputImages
inputNNImages.shape

# %%
split = train_test_split(df, inputNNImages, test_size=0.25, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split

trainY = np.log(trainAttrX["firmness"])
testY = np.log(testAttrX["firmness"])

# %%
#flatten the trainImagesX and testImagesX to convert from 3 dimensions to 1 dimension
nn_trainx = trainImagesX.reshape(trainImagesX.shape[0],-1)
nn_testx = testImagesX.reshape(testImagesX.shape[0],-1)
print(nn_trainx.shape)

# %%
# create our Neural Network and then compile the model
# using mean absolute percentage error as our loss, implying that we
# seek to minimize the absolute percentage difference between our
# predicted firmness and the actual firmness
model = models.create_mlp(387200, regress=True)
opt = Adam(lr=1e-4, decay=1e-3 / 200)
model.compile(loss="mean_squared_error", optimizer=opt)

nn_history = model.fit(x=nn_trainx, y=trainY, validation_data=(nn_testx, testY), epochs=125, batch_size=32) #try epochs=200 if this works

#firmness predictions for test data
nn_firmness_preds = model.predict(nn_testx)

#compute the difference between the firmness predictions and the actual firmness values, then compute the percentage 
#difference and the absolute percentage difference
#nn_diff = firmness_preds.flatten() - testY
#nn_percent_diff = (nn_diff / testY) * 100
#nn_absPercentDiff = np.abs(nn_percent_diff)

#mean and std deviation of absolute percentage difference
#nn_mean = np.mean(nn_absPercentDiff)
#nn_std = np.abs(nn_absPercentDiff)

# %%
import matplotlib.pyplot as plt

print(nn_history.history.keys())
# summarize history for accuracy
plt.plot(nn_history.history['loss'])
plt.plot(nn_history.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import pandas as pd
#testY = testAttrX["firmness"] / maxFirmness
#firmness predictions for test data
nn_firmness_preds = model.predict(nn_testx)
testY = pd.DataFrame(testY)
testY['preds'] = nn_firmness_preds.flatten()
testY.to_csv("/content/gdrive/MyDrive/Hyperspectral/hsdata50/nn_test_preds_125epochs_v1.csv", index=False)

# %%
d = {'train_loss': nn_history.history['loss'], 'test_loss': nn_history.history['val_loss']}
model_acc = pd.DataFrame(d)
model_acc.to_csv("/content/gdrive/MyDrive/Hyperspectral/hsdata/nn_model_acc_125epochs_v1.csv", index=False)
